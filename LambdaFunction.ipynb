# %% [markdown]
# A lambda function is an anonymous function without name

# %%
addition = lambda a,b : a+b

# %%
addition(14, 4)
# Out:
# 18

# %%
even = lambda a: a%2

# %%
even(4)
# Out:
# 0

# %%
even(5)
# Out:
# 1
